# %% [markdown]
# # 04과 단변량분석_숫자형변수_시각화

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EB%8B%A8%EB%B3%80%EB%9F%89%EB%B6%84%EC%84%9D.png?raw=true' width=400/>

# %% [markdown]
# ## 1.라이브러리 불러오기

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2.히스토그램

# %% [markdown]
# 1) 히스토그램 기본

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
plt.hist(age, bins = 5, edgecolor = 'gray')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 2) 구간의 갯수를 조정해 봅시다.

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
plt.hist(age, bins = 10, edgecolor = 'gray')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 3) 구간 값과 갯수를 확인해 봅시다.
#
# * 결과를 저장하면, 구간과 빈도수를 확인할 수 있습니다.
#     * 히스토그램을 저장하면 튜플.
#     * 튜플 안에는 넘파이 어레이가 2개로 구성됨.
#     * 첫번째 넘파이 어레이는 빈도수,
#     * 두번째는 구간 값.

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
hist1 = plt.hist(age, bins = 5, edgecolor = 'gray')

print(hist1)
print(type(hist1))
print('-' * 50)
print('빈도수 : ', hist1[0])
print('구간값 : ', hist1[1])
# Out:
# (array([6., 7., 4., 2., 1.]), array([19. , 24.4, 29.8, 35.2, 40.6, 46. ]), <BarContainer object of 5 artists>)
# <class 'tuple'>
# --------------------------------------------------
# 빈도수 :  [6. 7. 4. 2. 1.]
# 구간값 :  [19.  24.4 29.8 35.2 40.6 46. ]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 링크로 부터 ['Age', 'Fare'] 만 불러와서(usecols= ['Age', 'Fare']) 다음의 문제를 풀어 봅시다.
#
# https://bit.ly/3HaMAtZ

# %%
dadda = pd.read_csv('https://bit.ly/3HaMAtZ', usecols=['Age', 'Fare'])
dadda.head()
# Out:
#     Age     Fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %% [markdown]
# [문제1] Age에 칼럼에 대해 히스토그램을 그려 봅시다.
# * bins = 8, 16, 32, 64

# %%
# 1) Age에 칼럼에 대해 히스토그램을 그려 봅시다.
# bins = 8, 16, 32, 64
plt.subplot(2,2,1)
plt.hist(dadda['Age'],bins=8,edgecolor='grey')
plt.title('bins=8')
plt.subplot(2,2,2)
plt.hist(dadda['Age'],bins=16,edgecolor='grey')
plt.title('bins=16')
plt.subplot(2,2,3)
plt.hist(dadda['Age'],bins=32,edgecolor='grey')
plt.title('bins=32')
plt.subplot(2,2,4)
plt.hist(dadda['Age'],bins=64,edgecolor='grey')
plt.title('bins=64')
plt.tight_layout()
plt.show()

# %% [markdown]
# [문제2] Age에 칼럼에 대해 히스토그램을 그릴때, 빈도수와 구간값을 살펴 봅시다.
# * bins = 8

# %%
# Age에 칼럼에 대해 히스토그램을 그릴때, 
# 빈도수와 구간값을 살펴 봅시다.
# bins = 8
plt.hist(dadda['Age'],bins=8,edgecolor='grey')
print(hist1[0])
print(hist1[1])
plt.show()
# Out:
# [6. 7. 4. 2. 1.]
# [19.  24.4 29.8 35.2 40.6 46. ]

# %% [markdown]
# ## 3.밀도함수 그래프

# %% [markdown]
# * 히스토그램의 단점
#     * 구간bin의 너비를 어떻게 잡는지에 따라 전혀 다른 모양이 될 수 있음
#
# * 밀도함수 그래프
#     * 막대의 너비를 가정하지 않고 모든 점에서 데이터의 밀도를 추정하는 커널 밀도 추정(Kernel Density Estimation)방식을 사용하여 이러한 단점을 해결.
#     * 밀도함수 그래프 아래 면적은 1

# %% [markdown]
# 1) 밀도함수 그래프 그리기

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
age = pd.Series(age)
age.plot(kind = 'kde')
plt.show()

# %% [markdown]
# * 밀도 추정
#     * 측정된(관측된) 데이터로부터 전체 데이터 분포의 특성을 추정
#     * 예를 들어… OO역 사거리 일일 교통량을 측정한다고 해 봅시다.
#         * 어제는 1200대 차량이 통과했고, 오늘은 1420대, 내일은, 모레는…
#         * 이렇게 3개월간 매일 측정했다고 할 때,
#         * 우리는 약 90일치의 데이터를 가지고 일일 교통량 분포를 히스토그램으로 그려볼 수 있습니다.
#         * 그리고 나서 특정한 날의 교통량이 얼마나 될지 확률로 나타냄.

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EB%B0%80%EB%8F%84%EC%B6%94%EC%A0%95.png?raw=true' width=800/>

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]

# 히스토그램을 그리시오.
plt.hist(age,bins=5,edgecolor='grey')
plt.show()

# %%
# 밀도함수 그래프를 그리시오.
age = pd.Series(age)
age.plot(kind = 'kde')
plt.show()

# %%
# 두 그래프는 어떤 차이가 있나요?

# %% [markdown]
# ## 4.boxplot
#
# **주의사항** : 값에 **nan**이 있으면 그래프가 그려지지 않습니다.

# %% [markdown]
# 1) boxplot 기본

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
plt.boxplot(age)
plt.show()

# %% [markdown]
# 2) 옆으로 그리기

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
plt.boxplot(age, vert = False)
plt.show()

# %% [markdown]
# **박스플롯의 의미**

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EB%B0%95%EC%8A%A4%ED%94%8C%EB%A1%AF1.png?raw=true' width=600/>

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EB%B0%95%EC%8A%A4%ED%94%8C%EB%A1%AF2.png?raw=true' width=800/>

# %% [markdown]
# 3) 박스플로의 값들 가져오기

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
box1 = plt.boxplot(age)

print(type(box1))
print(box1.keys())
print('-'* 50)
print(box1['whiskers'])
print(box1['whiskers'][0].get_ydata()) # 아래쪽 수염의 max, min
print(box1['whiskers'][1].get_ydata()) # 위쪽 수염의 min, max
# Out:
# <class 'dict'>
# dict_keys(['whiskers', 'caps', 'boxes', 'medians', 'fliers', 'means'])
# --------------------------------------------------
# [<matplotlib.lines.Line2D object at 0x000002175FDFEF80>, <matplotlib.lines.Line2D object at 0x000002175FDFF250>]
# [24. 19.]
# [32.25 38.  ]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 링크로 부터 ['Age', 'Fare'] 만 불러와서 다음의 문제를 풀어 봅시다.
#
# https://bit.ly/3HaMAtZ

# %%
# Age에 칼럼에 대해 박스 플롯을 그려 봅시다.
data = pd.read_csv('https://bit.ly/3HaMAtZ', usecols=['Age', 'Fare'])
plt.boxplot(data['Age'])
plt.show()

# %%
# 박스 플롯을 옆으로 그려 봅시다.
plt.boxplot(data['Age'],vert=False)
plt.show()

# %%
# 박스 플롯의 아래 수염의 min, max, 윗 수염의 min, max를 구해 봅시다.
box = plt.boxplot(data['Age'])
print(box['whiskers'][0].get_ydata())
print(box['whiskers'][1].get_ydata())
# Out:
# [21.77  0.67]
# [35.9 57. ]

# %% [markdown]
# ## 5.바이올린 플롯
#
# **주의사항** : 값에 **nan**이 있으면 그래프가 그려지지 않습니다.

# %% [markdown]
# 1) 바이올린 플롯 그리기
#
# * 데이터의 분포와 범위를 한눈에 보기 쉽게 나타내는 그래프
# * 박스 플롯 (Box plot)과 비슷하지만 분포 함께 확인할 수 있음
# * vert = False : 가로로 그리기
# * showmeans = True : 평균 선 그리기
# * plt.text() : 평균값을 텍스트로 보여줘

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]
age_m = np.mean(age)

plt.violinplot(age, vert = False, showmeans=True)
plt.text( age_m - 1, 0.85 , age_m)
plt.show()

# %% [markdown]
# 2) 4가지 플롯을 한꺼번에 그려 봅시다.
#
# * Histogram : bin의 개수를 조절하며, 숲과 나무를 살펴볼 수 있음.
# * Densityplot : 연속된 분포를 볼 수 있다.
# * Boxplot : 분포를 단순화 하여 손쉽게 볼 수 있다. 이상치(Outlier)에 대한 기준 제시
# * Violinplot : Boxplot 과 Densityplot의 중간정도

# %%
age = [19,20,23,46,21,25,26,25,28,31,37,24,28,34,38,33,32,29,27,24]

plt.subplot(2,2,1)
plt.hist(age, bins = 8, edgecolor = 'grey')

plt.subplot(2,2,2)
plt.boxplot(age, vert = False)

plt.subplot(2,2,3)
pd.Series(age).plot(kind = 'kde')

plt.subplot(2,2,4)
plt.violinplot(age, vert = False, showmeans=True)

plt.show()

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 링크로 부터 ['Age', 'Fare'] 만 불러와서 다음의 문제를 풀어 봅시다.
#
# https://bit.ly/3HaMAtZ

# %%
# Age에 칼럼에 대해 

# 바이올린 플롯을 그려봅시다.
# 평균 값도 포함시켜 봅시다.

# %%
# 4가지 플롯을 한꺼번에 그려 봅시다.

# %% [markdown]
# ## 6.시계열 데이터 시각화

# %% [markdown]
# 시계열 데이터는 보통 시간 축(x축)에 맞게 값들을 라인차트로 표현합니다.

# %%
air = pd.read_csv('https://bit.ly/3qmthqZ')
air['Date'] = pd.to_datetime(air['Date']) # 날짜 형식으로 변환

plt.plot('Date', 'Ozone', 'g-', data = air, label = 'Ozone')
plt.plot('Date', 'Temp', 'r-', data = air, label = 'Temp')

plt.xlabel('Date')
plt.legend()
plt.show()

# %% [markdown]
# ## 7.종합실습

# %% [markdown]
# ### 1) Titanic 데이터프레임
#
# * url : 'https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv'

# %% [markdown]
# **[titanic_simple 데이터 셋 정보]**
#
# - PassengerId : 승객번호
# - Survived : 생존여부(1:생존, 0:사망)
# - Pclass : 객실등급(1:1등급, 2:2등급, 3:3등급)
# - Name : 승객이름
# - Sex : 성별(male, female)
# - Age : 나이
# - Fare : 운임($)
# - Embarked : 승선지역(Southhampton, Cherbourg, Queenstown)

# %% [markdown]
# ① 데이터를 불러와서 상위 5개 행을 조회하시오.

# %%
tita = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv')
tita.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#        Embarked
# 0  Southhampton
# 1     Cherbourg
# 2  Southhampton
# 3  Southhampton
# 4  Southhampton

# %% [markdown]
# ② 나이(Age)의 분포를 확인하기 위한 히스토그램을 그리시오.
#
# * bins : 8,16,32

# %%
plt.subplot(3,1,1)
plt.hist(tita['Age'],bins=8,edgecolor='grey')
plt.title('bins=8')
plt.subplot(3,1,2)
plt.hist(tita['Age'],bins=16,edgecolor='grey')
plt.title('bins=16')
plt.subplot(3,1,3)
plt.hist(tita['Age'],bins=32,edgecolor='grey')
plt.title('bins=32')
plt.tight_layout()
plt.show()

# %% [markdown]
# bins의 갯수를 조절함에 따라 다르게 파악되는 내용이 있나요?

# %% [markdown]
# ③ 나이(Age)의 분포를 확인하기 위한 네 가지 그래프(히스토그램, 밀도 함수 그래프, 박스플롯, 바이올린 플롯)을 한꺼번에 그리고 비교해 봅시다.

# %%
tita_test = tita.copy()
tita_test['Age'].fillna(0, inplace=True)

# %%
plt.subplot(2,2,1)
plt.hist(tita['Age'], bins = 8, edgecolor = 'grey')

plt.subplot(2,2,2)
plt.boxplot(tita_test['Age'], vert = False)

plt.subplot(2,2,3)
pd.Series(tita['Age']).plot(kind = 'kde')

plt.subplot(2,2,4)
plt.violinplot(tita_test['Age'], vert = False, showmeans=True)

plt.show()

# %% [markdown]
# ③ 위 분포로 부터 알수 있는 것은 무엇인가요?

# %% [markdown]
# ④ 운임(Fare)의 분포를 확인하기 위한 히스토그램을 그리시오.
#
# * bins : 10,20,50

# %%
plt.subplot(2,2,1)
plt.hist(tita['Fare'],bins=10,edgecolor='grey')
plt.title('bins=10')
plt.subplot(2,2,2)
plt.hist(tita['Fare'],bins=20,edgecolor='grey')
plt.title('bins=20')
plt.subplot(2,2,3)
plt.hist(tita['Fare'],bins=50,edgecolor='grey')
plt.title('bins=50')
plt.tight_layout()
plt.show()

# %% [markdown]
# bins의 갯수를 조절함에 따라 다르게 파악되는 내용이 있나요?

# %% [markdown]
# ⑤ 운임(Fare)의 분포를 확인하기 위한 네 가지 그래프(히스토그램, 밀도 함수 그래프, 박스플롯, 바이올린 플롯)를 한꺼번에 그리고 비교해 봅시다.

# %%
plt.subplot(2,2,1)
plt.hist(tita['Fare'], bins = 8, edgecolor = 'grey')

plt.subplot(2,2,2)
plt.boxplot(tita['Fare'], vert = False)

plt.subplot(2,2,3)
pd.Series(tita['Fare']).plot(kind = 'kde')

plt.subplot(2,2,4)
plt.violinplot(tita['Fare'], vert = False, showmeans=True)

plt.show()

# %% [markdown]
# ⑥ 위 분포로 부터 알수 있는 것은 무엇인가요?

# %% [markdown]
# ### 2) New York Air Quality
#
# * url : https://bit.ly/3qmthqZ

# %% [markdown]
# **[airquality 데이터 셋 정보]**
#
# - Ozone: 오존 농도
# - Solar.R: 태양복사량
# - Wind: 풍속
# - Temp: 기온
# - Month: 월
# - Day: 일

# %% [markdown]
# ① 데이터를 불러와서 상위 5개 행을 조회하시오.

# %%
air = pd.read_csv('https://bit.ly/3qmthqZ')
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp        Date
# 0     41    190.0   7.4    67  1973-05-01
# 1     36    118.0   8.0    72  1973-05-02
# 2     12    149.0  12.6    74  1973-05-03
# 3     18    313.0  11.5    62  1973-05-04
# 4     19      NaN  14.3    56  1973-05-05

# %% [markdown]
# ② 풍량(Wind)의 분포를 확인하기 위한 히스토그램을 주어진 결과에 맞게 그리시오.
# * color: skyblue
# * edge color: white
# * bins : 자유롭게 조절해 봅시다.

# %%
plt.hist(air['Wind'],bins=10,color='skyblue',edgecolor='white')
plt.show()

# %% [markdown]
# ③ 풍량(wind)의 분포를 확인하기 위한 네 가지 그래프(히스토그램, 밀도 함수 그래프, 박스플롯, 바이올린 플롯)를 한꺼번에 그리고 비교해 봅시다.

# %%
plt.subplot(2,2,1)
plt.hist(air['Wind'], bins = 10, edgecolor = 'grey')

plt.subplot(2,2,2)
plt.boxplot(air['Wind'], vert = False)

plt.subplot(2,2,3)
pd.Series(air['Wind']).plot(kind = 'kde')

plt.subplot(2,2,4)
plt.violinplot(air['Wind'], vert = False, showmeans=True)

plt.show()

# %% [markdown]
# ④ 위 분포로 부터 알수 있는 것은 무엇인가요?

# %% [markdown]
# ⑤ 태양복사열(Solar.R)의 분포를 확인하기 위한 히스토그램을 주어진 결과에 맞게 그리시오.
# * bins : 자유롭게 조절해 봅시다.

# %%
plt.hist(air['Solar.R'],bins=10,edgecolor='white')
plt.show()

# %% [markdown]
# ⑥ 태양복사열(Solar.R)의 분포를 확인하기 위한 네 가지 그래프(히스토그램, 밀도 함수 그래프, 박스플롯, 바이올린 플롯)를 한꺼번에 그리고 비교해 봅시다.

# %%
air_test = air.copy()
air_test['Solar.R'].fillna(0, inplace=True)

# %%
plt.subplot(2,2,1)
plt.hist(air['Solar.R'], bins = 10, edgecolor = 'grey')

plt.subplot(2,2,2)
plt.boxplot(air_test['Solar.R'], vert = False)

plt.subplot(2,2,3)
pd.Series(air['Solar.R']).plot(kind = 'kde')

plt.subplot(2,2,4)
plt.violinplot(air_test['Solar.R'], vert = False, showmeans=True)

plt.show()

# %% [markdown]
# ⑦ 위 분포로 부터 알수 있는 것은 무엇인가요?
