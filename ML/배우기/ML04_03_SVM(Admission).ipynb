# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# # 실습 내용
#
# - Admission 데이터로 모델링합니다.
# - SVM 알고리즘으로 모델링합니다.

# %% [markdown]
# # 1.환경 준비
#
# - 기본 라이브러리와 대상 데이터를 가져와 이후 과정을 준비합니다.

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/jangrae/csv/master/admission_simple.csv'
data = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해
#
# - 분석할 데이터를 충분히 이해할 수 있도록 다양한 탐색 과정을 수행합니다.

# %%
# 상위 몇 개 행 확인
data.head()
# Out:
#    GRE  TOEFL  RANK  SOP  LOR   GPA  RESEARCH  ADMIT
# 0  337    118     4  4.5  4.5  9.65         1      1
# 1  324    107     4  4.0  4.5  8.87         1      1
# 2  316    104     3  3.0  3.5  8.00         1      0
# 3  322    110     3  3.5  2.5  8.67         1      1
# 4  314    103     2  2.0  3.0  8.21         0      0

# %%
# 기초통계량 확인
data.describe()
# Out:
#               GRE       TOEFL        RANK         SOP        LOR         GPA  \
# count  500.000000  500.000000  500.000000  500.000000  500.00000  500.000000
# mean   316.472000  107.192000    3.114000    3.374000    3.48400    8.576440
# std     11.295148    6.081868    1.143512    0.991004    0.92545    0.604813
# min    290.000000   92.000000    1.000000    1.000000    1.00000    6.800000
# 25%    308.000000  103.000000    2.000000    2.500000    3.00000    8.127500
# 50%    317.000000  107.000000    3.000000    3.500000    3.50000    8.560000
# 75%    325.000000  112.000000    4.000000    4.000000    4.00000    9.040000
# max    340.000000  120.000000    5.000000    5.000000    5.00000    9.920000
#
#          RESEARCH       ADMIT
# count  500.000000  500.000000
# mean     0.560000    0.436000
# std      0.496884    0.496384
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      1.000000    0.000000
# 75%      1.000000    1.000000
# max      1.000000    1.000000

# %%
# 범주값 개수 확인
data['ADMIT'].value_counts()
# Out:
# 0    282
# 1    218
# Name: ADMIT, dtype: int64

# %%
# 상관관계 확인
data.corr()
# Out:
#                GRE     TOEFL      RANK       SOP       LOR       GPA  \
# GRE       1.000000  0.827200  0.635376  0.613498  0.524679  0.825878
# TOEFL     0.827200  1.000000  0.649799  0.644410  0.541563  0.810574
# RANK      0.635376  0.649799  1.000000  0.728024  0.608651  0.705254
# SOP       0.613498  0.644410  0.728024  1.000000  0.663707  0.712154
# LOR       0.524679  0.541563  0.608651  0.663707  1.000000  0.637469
# GPA       0.825878  0.810574  0.705254  0.712154  0.637469  1.000000
# RESEARCH  0.563398  0.467012  0.427047  0.408116  0.372526  0.501311
# ADMIT     0.701671  0.680503  0.618367  0.606876  0.536527  0.752196
#
#           RESEARCH     ADMIT
# GRE       0.563398  0.701671
# TOEFL     0.467012  0.680503
# RANK      0.427047  0.618367
# SOP       0.408116  0.606876
# LOR       0.372526  0.536527
# GPA       0.501311  0.752196
# RESEARCH  1.000000  0.503104
# ADMIT     0.503104  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GRE       500 non-null    int64
#  1   TOEFL     500 non-null    int64
#  2   RANK      500 non-null    int64
#  3   SOP       500 non-null    float64
#  4   LOR       500 non-null    float64
#  5   GPA       500 non-null    float64
#  6   RESEARCH  500 non-null    int64
#  7   ADMIT     500 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 31.4 KB

# %% [markdown]
# # 3.데이터 준비
#
# - 전처리 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# **1) x, y 분리**

# %%
# target 확인
target = 'ADMIT'

# 데이터 분리
# x = data.drop(target, axis=1)
x = data[['GRE', 'GPA']]
y = data[target]

# %%
# 정규화
x = (x - x.min()) / (x.max() - x.min())

# %% [markdown]
# **2) 학습용, 평가용 데이터 분리**

# %%
# 모듈 불러오기
from sklearn.model_selection import train_test_split

# 7:3으로 분리
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2022)

# %% [markdown]
# # 4.모델링
#
# - 본격적으로 모델을 **선언**하고 **학습**하고 **평가**하는 과정을 진행합니다.

# %%
# 1단계: 불러오기
from sklearn.svm import SVC
from sklearn.metrics import *

# %%
# 2단계: 선언하기
model = SVC(kernel='rbf', C=100)

# %%
# 3단계: 학습하기
model.fit(x_train, y_train)
# Out:
# SVC(C=100)

# %%
# 4단계: 예측하기
y_pred = model.predict(x_test)

# %%
# 5단계 평가하기
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[80  3]
#  [ 8 59]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94        83
#            1       0.95      0.88      0.91        67
#
#     accuracy                           0.93       150
#    macro avg       0.93      0.92      0.93       150
# weighted avg       0.93      0.93      0.93       150

# %%
# 회귀 계수 확인(linear만 결과 출력 가능)
print(model.coef_)
print(model.intercept_)

# coef_0 = model.coef_[0][0]
# coef_1 = model.coef_[0][1]
# intercept = model.intercept_
# y = -(coef_0 / coef_1)*x - intercept/coef_1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\myblo\바탕 화면\2022\aivle2201\ML\배우기\ML04_03_SVM(Admission).ipynb Cell 24' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/myblo/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/2022/aivle2201/ML/%EB%B0%B0%EC%9A%B0%EA%B8%B0/ML04_03_SVM%28Admission%29.ipynb#ch0000023?line=0'>1</a> # 회귀 계수 확인(linear만 결과 출력 가능)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/myblo/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/2022/aivle2201/ML/%EB%B0%B0%EC%9A%B0%EA%B8%B0/ML04_03_SVM%28Admission%29.ipynb#ch0000023?line=1'>2</a> print(model.coef_)
#       <a href='vscode-notebook-cell:/c%3A/Users/myblo/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/2022/aivle2201/ML/%EB%B0%B0%EC%9A%B0%EA%B8%B0/ML04_03_SVM%28Admission%29.ipynb#ch0000023?line=2'>3</a> print(model.intercept_)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:637, in BaseLibSVM.coef_(self)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=629'>630</a> """Weights assigned to the features when `kernel="linear"`.
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=630'>631</a>
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=631'>632</a> Returns
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=632'>633</a> -------
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=633'>634</a> ndarray of shape (n_features, n_classes)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=634'>635</a> """
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=635'>636</a> if self.kernel != "linear":
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=636'>637</a>     raise AttributeError("coef_ is only available when using a linear kernel")
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=638'>639</a> coef = self._get_coef()
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=640'>641</a> # coef_ being a read-only property, it's better to mark the value as
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/svm/_base.py?line=641'>642</a> # immutable to avoid hiding potential bugs for the unsuspecting user.
#
# AttributeError: coef_ is only available when using a linear kernel

# %%
#  시각화
xx = np.linspace(0, 1, 30)
yy = np.linspace(0, 1, 30)
yy, xx = np.meshgrid(yy, xx)
xy = np.vstack([xx.ravel(), yy.ravel()]).T
z = model.decision_function(xy).reshape(xx.shape)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=x_train['GRE'], y=x_train['GPA'], hue=y, s=50)
# plt.scatter(model.support_vectors_[:, 0], 
#             model.support_vectors_[:, 1], 
#             s=80,
#             linewidth=1,
#             facecolors='none', 
#             color='r')
plt.contour(xx, yy, z, 
            colors='k', 
            levels=[-1, 0, 1], 
            alpha=0.5,
            linestyles=['--', '-', '--'])

plt.xlabel('GRE')
plt.ylabel('GPA')
plt.show()
