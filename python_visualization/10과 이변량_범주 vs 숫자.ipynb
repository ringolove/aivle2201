# %% [markdown]
# # 10과 이변량_범주 vs 숫자

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import random as rd

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as spst

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > 타이타닉 생존자

# %% [markdown]
# |	변수	|	설명	|	값 설명	|
# |	----	|	----	|	----	|
# |	survived	|	생존여부	|	0 - 사망, 1- 생존	|
# |	Pclass	|	Ticket class	|	1 = 1st, 2 = 2nd, 3 = 3rd	|
# |	Sex	|	성별	|		|
# |	Age	|	Age in years	|		|
# |	Sibsp	|	# of siblings / spouses aboard the Titanic	|		|
# |	Parch	|	# of parents / children aboard the Titanic	|		|
# |	Ticket	|	Ticket number	|		|
# |	Fare	|	Passenger fare	|		|
# |	Cabin	|	Cabin number	|		|
# |	Embarked	|	Port of Embarkation	|	C = Cherbourg, Q = Queenstown, S = Southampton	|

# %%
# 타이타닉 데이터
titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.0.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 범주별 숫자를 비교할 때 사용되는 방식은 **범주별 평균 비교** 입니다.

# %% [markdown]
# ## 2.평균비교

# %% [markdown]
# ### 평균
#
# * 범주 ==> 숫자 의 관계를 살펴볼 때 중요한 관점은 ‘평균비교’ 입니다.
#
# * 평균을 비교할 때는 두 가지를 고려해야 합니다.
#     * ① 평균값이 그 집단을 대표할 수 있는가?
#     * ② 평균값이 믿을 만 한가?

# %% [markdown]
# ### 1) 평균값이 그 집단을 대표할 수 있는가?

# %%
s0 = titanic.loc[titanic['Survived']==0, 'Age']
s1 = titanic.loc[titanic['Survived']==1, 'Age']

# %%
# 사망자의 나이 분포
sns.histplot(s0, bins = 16)
plt.axvline(s0.mean(), color='r')
plt.show()

# %%
# 생존자의 나이 분포
sns.histplot(s1, bins = 16)
plt.axvline(s1.mean(), color='r')
plt.show()

# %% [markdown]
# * 평균이 집단을 대표하지 못할때..
#
# > 평균의 함정 : https://www.youtube.com/watch?v=Pp_Pd6GZLOE

# %%
# 임의의 한 집단을 만들어 봅시다.
pop = [round(rd.normalvariate(10, 5),1) for i in range(1000)] + [round(rd.normalvariate(38, 8),1) for i in range(750)]
mn = np.mean(pop)
print(mn)
# Out:
# 22.013485714285718

# %%
# 히스토그램으로 집단의 대표값이 될 수 있는지 살펴봅시다.
plt.figure(figsize=(10,6))
sns.histplot(pop, bins = 50)
plt.axvline(mn, color='r')
plt.text(mn+1, 110, "mean : {}".format(round(mn,2)), color = 'r')
plt.show()

# %% [markdown]
# ### 2) 평균값을 믿을 만 한가?

# %% [markdown]
# * 표본 조사를 수행하기로 결정하였을 때,다음 두가지 조사의 오차에 대해서 생각해 봅시다.
#     * 조사1 : 전국 성인 10명을 무작위로 뽑아서, 키를 재고 그 평균을 계산했더니 174 cm
#     * 조사2 : 전국 성인 1000명을 무작위로 뽑아서, 키를 재고 그 평균을 계산했더니 166 cm
#
# * 어떤 조사 결과가 전국 성인의 평균키와 더 가까울 까요? 어떤 조사 결과가 **오차**가 더 적을 까요?

# %% [markdown]
# * 평균이 믿을만 한지는 오차로 평가해야 합니다.
#     * 표준편차
#     * 표준오차

# %% [markdown]
# ### 3) 표준편차(SD, Standard Deviation)
# * 한 집단을 설명하기 위해서
# * 그 집단 안에서 대푯값으로 평균을 구할 때
# * 값들이 평균으로부터 얼마나 벗어나 있는지(이탈도, deviation)를 나타내는 값.
#     * 예 : 우리 반 수학 성적의 평균이 91, 표준편차는 10

# %%
a = np.array([23,54,47,64,29,15])

print(f'평균 : {a.mean()}')
print(f'표준편차 : {a.std()}')
# Out:
# 평균 : 38.666666666666664
# 표준편차 : 17.53726191728787

# %% [markdown]
# 평균 38.6, 표준편차 17.5는 집단 a를 설명(대표)하는 숫자 입니다.

# %%
# 표준편차
titanic.groupby('Survived')['Age'].agg(['mean','std'])
# Out:
#                mean        std
# Survived
# 0         30.626179  14.172110
# 1         28.343690  14.950952

# %% [markdown]
# ### 4) 표준오차(SE, standard error)
# * 표준오차는 표준편차와 다른 개념입니다. (표준 편차와 비교하는 개념이 아닙니다!)
# * 우선 **표본(의) 평균**을 이해해야 합니다.
# * 표본을 뽑아내는(표집, sampling) 목적은, 모집단을 추정하기 위함 입니다.
#     * 표본평균을 계산한다는 의미는, 표본의 평균으로 모집단의 평균을 **추정**하기 위함 입니다.(**추정치**)
#     * 표본의 평균을 계산하면, 표본 자체의 평균이라는 의미가 아니라, 모평균을 표본으로 추정한 평균치 입니다.
#     * 그래서 표본평균 하면 항상 모평균을 의식해야 합니다.
# * 그런데 표본평균은 모평균과 완전히 일치할 수는 없습니다.
# * 이 오차를 **표준오차** 라고 합니다.
#
# * 표준오차 공식 : 𝑠/√𝑛
#     * 샘플의 표준 편차 : s
#     * 데이터 건수 : n
# * 표준 오차로 부터 신뢰구간을 계산하게 됩니다.

# %% [markdown]
# * 몇가지 기호에 대해서
#
# <img src='https://github.com/DA4BAM/image/blob/main/%EA%B8%B0%ED%98%B8.png?raw=true' width=500/>

# %%
# 표준오차
titanic.groupby('Survived')['Age'].agg(['mean','std','sem'])
# Out:
#                mean        std       sem
# Survived
# 0         30.626179  14.172110  0.688258
# 1         28.343690  14.950952  0.877950

# %% [markdown]
# ### 5) 95% 신뢰구간

# %% [markdown]
# * 모집단을 하나 준비합니다.

# %%
# 임의의 모집단을 하나 만듭시다.
pop2 = [round(rd.normalvariate(160, 10),1) for i in range(100000)]

# %%
# 우리는 모집단을 알 수 없지만. 그래도 살짝 살펴봅시다. (보고 나서 못 본 것으로 합시다.ㅎㅎ)

plt.figure(figsize=(10,6))
sns.histplot(pop2, bins = 100)
plt.axvline(np.mean(pop2), color = 'r')
plt.text(np.mean(pop2)+1, 3600, f'pop mean : {np.mean(pop2).round(2)}', color = 'r')
plt.show()

# %% [markdown]
# * 표본 조사를 합니다.
#     * 100명을 임의로 샘플링 해서
#     * 표본의 평균과, 표준 오차, 신뢰구간을 계산해 봅시다.

# %%
# 표본조사를 합니다. 100건
s1 = rd.sample(pop2,100)
s1 = pd.Series(s1)
s1.mean(), s1.std(), s1.sem()
# Out:
# (160.284, 9.228017504898173, 0.9228017504898173)

# %%
1.96 * s1.sem()
# Out:
# 1.808691430960042

# %%
# 95% 신뢰구간
s1.mean() - (1.96 * s1.sem()), s1.mean() + (1.96 * s1.sem())
# Out:
# (158.47530856903995, 162.09269143096003)

# %% [markdown]
# * 표본평균의 신뢰구간과 모평균을 비교해 봅시다.

# %%
# 모평균은?
np.mean(pop2)
# Out:
# 159.948194

# %% [markdown]
# * 95% 신뢰구간에 대한 실험을 해 봅시다.
#     * 샘플조사를 100번 수행합니다.
#     * 그때마다 신뢰구간을 계산한 후
#     * 그 중 몇번이 모평균을 포함하는지 확인해 봅시다.
#     * 95% 신뢰구간이라면, 100번 중 95번은 모평균을 포함해야 합니다.

# %%
# 100번 샘플링
samples = { 'id' : [], 'value' : []}
for i in range(100) :
    samples['id'] += [i]* 100
    samples['value'] += rd.sample(pop2,100)

samples = pd.DataFrame(samples)
samples.shape
# Out:
# (10000, 2)

# %%
# errorbar 라는 차트 입니다. 
# 신뢰구간, 표준오차 구간을 시각화 하는 방법입니다.

plt.figure(figsize = (18, 8))
sns.pointplot(x = 'id', y = 'value', data = samples, join = False)
plt.axhline(np.mean(pop2), color = 'r')
plt.show()

# %% [markdown]
# 위 그래프에 대한 해석
# * x축은 100번 시도에 대한 순번(인덱스)
# * y축은 모평균(빨간 선)을 추정하기 위한 샘플의 평균과, 신뢰구간 표시

# %% [markdown]
# ### (참조) 중심극한 정리

# %% [markdown]
# * 표본이 클수록 표집분포는 정규분포에 가까와 진다.

# %% [markdown]
# * 임의의 모집단을 하나 만듭니다.

# %%
pop = [round(rd.expovariate(.3)+165,2) for i in range(10000)]

# %% [markdown]
# * ① 모집단으로 부터 데이터 n개 짜리 표본을 뽑아 표본평균을 계산합니다.
# * ② ①번 작업을 m번 반복하여 얻은 표본평균 m개로 분포를 그려봅니다.

# %%
# 표본의 크기
n = 30

# 표본의 갯수
m = 100

sample_mean = [np.mean(rd.sample(pop,n)) for i in range(m)]

plt.figure(figsize=(10,6))
sns.kdeplot(sample_mean)
plt.xlim(160,180)

plt.axvline(x=np.mean(sample_mean), color = 'red') #표본평균들의 평균
plt.axvline(x=np.mean(pop), color = 'grey') # 모평균

plt.text(np.mean(sample_mean)-1.5, 0.02, round(np.mean(sample_mean),2), color = 'red') #표본평균들의 평균
plt.text(np.mean(pop)+.5,0.02, round(np.mean(pop),2), color = 'grey') #모평균

plt.show() # show

# %% [markdown]
# * 그렇다면, 모집단은 어떤 분포일까?

# %%
plt.figure(figsize=(10,6)) #설정
sns.histplot(pop, bins = 100)
plt.axvline(x=np.mean(pop), color = 'grey') # 모평균
plt.text(np.mean(pop)+.5, 800, round(np.mean(pop),2), color = 'grey')
plt.show()

# %% [markdown]
# ## 3.범주 --> 숫자
#
# titanic data에서 Age를 Y로 두고 비교해 봅시다.

# %% [markdown]
# ### 1) 시각화 : 평균 비교 barplot, boxplot

# %%
# sns.barplot는 두 범주의 평균 비교 sns.barplot
sns.barplot(x="Survived", y="Age", data=titanic)
plt.show()

# %% [markdown]
# 위 두 범주간에 평균에 차이가 있나요?

# %% [markdown]
# > 평균에는 차이가 있으나 신뢰구간이 겹치므로 큰 차이가 없다

# %%
# 박스플롯으로 비교해 봅시다.
titanic.boxplot('Age', 'Survived')
plt.show()

# %% [markdown]
# ### 2)수치화 : t-test(두 범주), anova(세 범주 이상)

# %% [markdown]
# #### ①t-test
# 두 집단의 평균을 비교합니다.
# * 예제는 Two sample T-test와 양측검정만 다룹니다.
# * 우리는 X --> Y의 관계에서 ,두 변수간에 관련이(차이가) 있는지, 없는지를 확인하는 것이 제일 중요하기 때문입니다.
#
# * 주의사항 : 데이터에 NaN이 있으면 계산이 안됩니다. .notnull() 등으로 NaN을 제외한 데이터를 사용해야 합니다.
#
# * t 통계량
#     * 두 평균의 차이를 표준오차로 나눈 값.
#     * 기본적으로는 두 평균의 차이로 이해해도 좋습니다.
#     * 우리의 가설(대립가설)은 차이가 있다는 것이므로, t 값이 크던지 작던지 하기를 바랍니다.
#     * 보통, t 값이 -2보다 작거나, 2보다 크면 차이가 있다고 봅니다.

# %%
import scipy.stats as spst
import numpy as np
import random as rd

# %%
# 모집단 만들기
pop1 = [round(rd.normalvariate(160, 10),1) for i in range(100000)]
pop2 = [round(rd.normalvariate(170, 10),1) for i in range(100000)]

# %%
# 우리는 모집단을 알 수 없지만. 그래도 살짝 살펴봅시다.
plt.figure(figsize=(10,6))
sns.distplot(pop1, hist=False, kde=True)
sns.distplot(pop2, hist=False, kde=True)
plt.show()
# Out:
# C:\Users\myblo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\myblo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# 표본을 추출합니다. 먼저 pop1으로 부터 두 샘플을 추출합시다.
s1 = rd.sample(pop1,100)
s2 = rd.sample(pop1,100)

# %%
# t-test
spst.ttest_ind(s1, s2)
# Out:
# Ttest_indResult(statistic=0.13142975750616986, pvalue=0.8955687990221957)

# %% [markdown]
# p.value의 의미는?

# %%
# 이번에는 두 모집단으로 부터 각각 샘플링
s1 = rd.sample(pop1,100)
s2 = rd.sample(pop2,100)

# %%
# t-test
spst.ttest_ind(s1, s2)
# Out:
# Ttest_indResult(statistic=-8.274541708885124, pvalue=1.8752290063109914e-14)

# %% [markdown]
# p.value의 의미는?

# %% [markdown]
# * 이번엔 타이타닉 데이터로 시도해 봅시다.
#     * 생존여부 --> Age : 생존여부 별로 나이에 차이가 있을것이다.

# %%
# 먼저 NaN이 있는지 확인해 봅시다.
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
temp = titanic.loc[titanic['Age'].notnull()]
died = temp.loc[temp['Survived']==0, 'Age']
survived = temp.loc[temp['Survived']==1, 'Age']

# %%
spst.ttest_ind(died, survived)
# Out:
# Ttest_indResult(statistic=2.06668694625381, pvalue=0.03912465401348249)

# %% [markdown]
# #### 실습 : t-test
#
# 성별에 따라 운임에 차이가 있을 것이다.

# %%
sns.barplot(x='Sex',y='Fare',data=titanic)
plt.show()

# %%
# 먼저 성별 별로 나누기
male = temp.loc[temp['Sex']=='male', 'Fare']
female = temp.loc[temp['Sex']=='female', 'Fare']

# %%
spst.ttest_ind(female, male)
# Out:
# Ttest_indResult(statistic=5.022960682752043, pvalue=6.439279020446988e-07)

# %% [markdown]
# #### ②anova
#
# * 분산 분석 **AN**alysis **O**f **VA**riance
# * 여러 집단 간에 차이는 어떻게 비교할 수 있을까요?
# * 여기서 기준은 전체 평균 입니다.
# * 𝐹 통계량 =
#     * (집단 간 분산)/(집단 내 분산) = (전체 평균 − 각 집단 평균)/(각 집단의 평균 − 개별 값)
#     * 값이 대략 2~3 이상이면 차이가 있다고 판단합니다.

# %%
# Pclass(3 범주) --> Age
sns.barplot(x="Pclass", y="Age", data=titanic)
plt.show()

# %%
titanic.boxplot('Age', 'Pclass')
plt.show()

# %%
P_1 = titanic.loc[titanic.Pclass == 1, 'Age']
P_2 = titanic.loc[titanic.Pclass == 2, 'Age']
P_3 = titanic.loc[titanic.Pclass == 3, 'Age']

# %%
spst.f_oneway(P_1, P_2, P_3)
# Out:
# F_onewayResult(statistic=nan, pvalue=nan)

# %% [markdown]
# #### 실습 ANOVA
#
# 승선지역(Embarked)별로 운임에 차이가 있을 것이다.
# * 시각화와 수치화로 확인해 봅시다.

# %%
# Embarked(3 범주) --> Fare
sns.barplot(x="Fare", y="Embarked", data=titanic)
plt.show()

# %%
# 분산분석

E_S = titanic.loc[titanic.Embarked == 'S', 'Fare']
E_C = titanic.loc[titanic.Embarked == 'C', 'Fare']
E_Q = titanic.loc[titanic.Embarked == 'Q', 'Fare']

spst.f_oneway(E_S, E_C, E_Q)
# Out:
# F_onewayResult(statistic=38.14030520011266, pvalue=1.2896450252631794e-16)

# %% [markdown]
# # 종합실습

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import random as rd

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as spst

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > ① 타이타닉 생존자
# ② 카시트 매출액

# %% [markdown]
# ① 타이타닉 생존자

# %% [markdown]
# |	변수	|	설명	|	값 설명	|
# |	----	|	----	|	----	|
# |	survived	|	생존여부	|	0 - 사망, 1- 생존	|
# |	Pclass	|	Ticket class	|	1 = 1st, 2 = 2nd, 3 = 3rd	|
# |	Sex	|	성별	|		|
# |	Age	|	Age in years	|		|
# |	Fare	|	Passenger fare	|		|
# |	Embarked	|	Port of Embarkation	|	C = Cherbourg, Q = Queenstown, S = Southampton	|

# %%
# 타이타닉 데이터
titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.1.csv', 
                      usecols = ['Survived','Pclass','Sex','Age','Fare','Embarked'])
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked
# 0         0       3    male  22.0   7.2500        S
# 1         1       1  female  38.0  71.2833        C
# 2         1       3  female  26.0   7.9250        S
# 3         1       1  female  35.0  53.1000        S
# 4         0       3    male  35.0   8.0500        S

# %% [markdown]
# ② 카시트 매출액

# %% [markdown]
# |	변수명	|	설명	|	구분	|
# |	----	|	----	|	----	|
# |	Sales 	|	 각 지역 판매액(단위 : 1000달러)	|	Target	|
# |	CompPrice 	|	 경쟁사 가격(단위 : 달러)	|	feature	|
# |	Income 	|	 지역 평균 소득(단위 : 1000달러)	|	feature	|
# |	Advertising 	|	 각 지역, 회사의 광고 예산(단위 : 1000달러)	|	feature	|
# |	Population 	|	 지역 인구수(단위 : 1000명)	|	feature	|
# |	Price 	|	 자사 지역별 판매가격	|	feature	|
# |	ShelveLoc 	|	 진열상태	|	feature	|
# |	Age 	|	 지역 인구의 평균 연령	|	feature	|
# |	Urban 	|	 도심 지역 여부(0,1)	|	feature	|
# |	US 	|	 매장이 미국에 있는지 여부(0,1)	|	feature	|

# %%
# 카시트 매출액
path = 'https://raw.githubusercontent.com/JunhoYu/Data-Analysis/main/Carseats.csv'
carseat = pd.read_csv(path)
carseat.drop('Education', axis = 1, inplace = True)
carseat.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %% [markdown]
# ## 2.범주 --> 숫자 : 시각화

# %% [markdown]
# ① titanic 생존여부에 따라 나이에 차이가 있을까요?
# * 평균 barplot으로 시각화 해 봅시다.

# %%
sns.barplot(x='Survived',y='Age',data=titanic)
plt.show()

# %% [markdown]
# * 박스플롯으로 시각화 해 봅시다.

# %%
titanic.boxplot('Age','Survived')
plt.show()

# %% [markdown]
# * 위 두 범주간에 평균에 차이가 있나요?

# %% [markdown]
# > 차이가 있으나 확연히 드러나지 않음

# %% [markdown]
# ② titanic 성별에 따라 운임에 차이가 있을까요?
# * 평균 barplot으로 시각화 해 봅시다.

# %%
sns.barplot(x='Sex',y='Fare',data=titanic)
plt.show()

# %% [markdown]
# * 박스플롯으로 시각화 해 봅시다.

# %%
titanic.boxplot('Fare', 'Sex')
plt.show()

# %% [markdown]
# * 위 범주간 평균에 차이가 있나요?

# %% [markdown]
# > 예

# %% [markdown]
# ③ titanic 승선지역(Embarked)에 따라 나이에 차이가 있을까요?
# * 평균 barplot으로 시각화 해 봅시다.

# %%
sns.barplot(x='Embarked',y='Age',data=titanic)
plt.axhline(titanic['Age'].mean(),color='k')
plt.show()

# %% [markdown]
# * 박스플롯으로 시각화 해 봅시다.

# %%
titanic.boxplot('Age', 'Embarked')
plt.show()

# %% [markdown]
# * 위 범주간 평균에 차이가 있나요?

# %% [markdown]
# > 차이의 확인이 어려움

# %% [markdown]
# ④ carseat의 국내외여부(US)에 따라 매출액(Sales)에 차이가 있을까요?
# * 평균 barplot으로 시각화 해 봅시다.

# %%
sns.barplot(x='US',y='Sales',data=carseat)
plt.show()

# %% [markdown]
# * 박스플롯으로 시각화 해 봅시다.

# %%
carseat.boxplot('Sales', 'US')
plt.show()

# %% [markdown]
# ⑤ carseat의 진열상태(ShelveLoc)에 따라 매출액(Sales)에 차이가 있을까요?
# * 평균 barplot으로 시각화 해 봅시다.

# %%
sns.barplot(x='ShelveLoc',y='Sales',data=carseat)
plt.axhline(carseat['Sales'].mean(),color='k')
plt.show()

# %% [markdown]
# * 박스플롯으로 시각화 해 봅시다.

# %%
carseat.boxplot('Sales', 'ShelveLoc')
plt.show()

# %% [markdown]
# * 위 범주간 평균에 차이가 있나요?

# %% [markdown]
# > 진열상태에 따른 평균 차이가 크게 있다

# %% [markdown]
# ## 3.수치화 : t-test(두 범주), anova(세 범주 이상)

# %% [markdown]
# ① titanic 생존여부에 따라 나이에 차이가 있을까요?

# %% [markdown]
# * t-test를 수행해 봅시다.

# %%
# 먼저 성별 별로 나누기
temp = titanic.loc[titanic['Age'].notnull()]
died = temp.loc[temp['Survived']==0, 'Age']
survived = temp.loc[temp['Survived']==1, 'Age']

# %%
spst.ttest_ind(died,survived) # died - survived
# Out:
# Ttest_indResult(statistic=2.6686741711011606, pvalue=0.007753857024893962)

# %%
spst.ttest_ind(survived,died) # survived - died
# Out:
# Ttest_indResult(statistic=-2.6686741711011606, pvalue=0.007753857024893962)

# %% [markdown]
# * t-test 결과를 해석해 봅시다.

# %% [markdown]
# > 차이가 있다

# %% [markdown]
# ② titanic 성별에 따라 운임에 차이가 있을까요?

# %% [markdown]
# * t-test를 수행해 봅시다.

# %%
male = temp.loc[temp['Sex']=='male', 'Fare']
female = temp.loc[temp['Sex']=='female', 'Fare']

# %%
spst.ttest_ind(male,female)
# Out:
# Ttest_indResult(statistic=-5.529140269385719, pvalue=4.230867870042998e-08)

# %% [markdown]
# * t-test 결과를 해석해 봅시다.

# %% [markdown]
# > 차이가 매우 크게남

# %% [markdown]
# ③ titanic 승선지역(Embarked)에 따라 나이에 차이가 있을까요?

# %% [markdown]
# * 분산분석(anova)을 수행해 봅시다.

# %%
E_S = titanic.loc[titanic.Embarked == 'S', 'Age']
E_C = titanic.loc[titanic.Embarked == 'C', 'Age']
E_Q = titanic.loc[titanic.Embarked == 'Q', 'Age']

# %%
spst.f_oneway(E_S, E_C, E_Q)
# Out:
# F_onewayResult(statistic=1.5519517205674485, pvalue=0.2124081352616724)

# %% [markdown]
# * anova 결과를 해석해 봅시다.

# %% [markdown]
# > 차이가 거의 없다

# %% [markdown]
# ④ carseat의 국내외여부(US)에 따라 매출액(Sales)에 차이가 있을까요?

# %% [markdown]
# * t-test를 수행해 봅시다.

# %%
carseat.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %%
no = carseat.loc[carseat['US']=='No', 'Sales']
yes = carseat.loc[carseat['US']=='Yes', 'Sales']

# %%
spst.ttest_ind(no,yes)
# Out:
# Ttest_indResult(statistic=-3.589738747802499, pvalue=0.00037233958701471517)

# %% [markdown]
# * t-test 결과를 해석해 봅시다.

# %% [markdown]
# ⑤ carseat의 진열상태(ShelveLoc)에 따라 매출액(Sales)에 차이가 있을까요?

# %%
carseat['ShelveLoc'].value_counts()
# Out:
# Medium    219
# Bad        96
# Good       85
# Name: ShelveLoc, dtype: int64

# %% [markdown]
# * 분산분석(anova)을 수행해 봅시다.

# %%
m = carseat.loc[carseat['ShelveLoc']=='Medium','Sales']
b = carseat.loc[carseat['ShelveLoc']=='Bad','Sales']
g = carseat.loc[carseat['ShelveLoc']=='Good','Sales']

# %%
spst.f_oneway(m,b,g)
# Out:
# F_onewayResult(statistic=92.22990509910348, pvalue=1.26693609015938e-33)

# %% [markdown]
# * anova 결과를 해석해 봅시다.
