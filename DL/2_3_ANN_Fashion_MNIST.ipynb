# %% [markdown]
# # ANN
#
# # Fashion MNIST
#
#
# <br> By Margaret Maynard-Reid, 4/24/2018
#
# ![alt text](https://github.com/margaretmz/deep-learning/blob/master/images/modern%20dl_fash-mnist_keras.png?raw=1)

# %% [markdown]
# ## Why Fashion-MNIST?
#
#
# *   MNIST is too easy
# *   MNIST is overused
# *   MNIST can not represent modern Computer Vision tasks
#
# Read more about the Fashion-MINST dataset in this paper [here](https://arxiv.org/abs/1708.07747) (**Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning Algorithms**)

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# Load the fashion-mnist pre-shuffled train data and test data
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)
# Out:
# x_train shape: (60000, 28, 28) y_train shape: (60000,)

# %% [markdown]
# ## Visualize the data 반복실행 해보자

# %%
# Print training set shape - note there are 60,000 training data of image size of 28x28, 60,000 train labels)
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# Print the number of training and test datasets
print(x_train.shape[0], 'train set')
print(x_test.shape[0], 'test set')

# Define the text labels
fashion_mnist_labels = ["T-shirt/top",  # index 0
                        "Trouser",      # index 1
                        "Pullover",     # index 2 
                        "Dress",        # index 3 
                        "Coat",         # index 4
                        "Sandal",       # index 5
                        "Shirt",        # index 6 
                        "Sneaker",      # index 7 
                        "Bag",          # index 8 
                        "Ankle boot"]   # index 9

# Image index, you can pick any number between 0 and 59,999
img_index = np.random.randint(0, 59999)
# y_train contains the lables, ranging from 0 to 9
label_index = y_train[img_index]
# Print the label, for example 2 Pullover
print ("y = " + str(label_index) + " " +(fashion_mnist_labels[label_index]))
# # Show one of the images from the training dataset
plt.imshow(x_train[img_index])
# Out:
# x_train shape: (60000, 28, 28) y_train shape: (60000,)
# 60000 train set
# 10000 test set
# y = 1 Trouser

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28) (60000,) (10000,)

# %% [markdown]
# ##  코딩 task!
#
# 1. 전처리
#     * x : sc_____
#     * y : _______ encoding
#
# 2. 모델링
#     * model에 모델 선언
#     * Input layer에 어떻게 전달할 것인지 고민 필요
#     * 쭈우우우욱 늘려주는 레이어를 사용할 것 (F______)
#     * 히든레이어는 최소 3개를 쓸 것!
#     * 노드 수는 512개를 기본으로 시작
#     * 자유롭게 바꿔가며 성능을 볼 것
#
# 3. 학습
#     * epochs=50, validation_split=0.2
#     * early stopping

# %%
#############
# Your Code # 전처리
#############
max_n = x_train.max()

x_train = x_train/max_n
x_test = x_test/max_n

x_train.max(), x_train.min()
# Out:
# (1.0, 0.0)

# %%
#############
# Your Code #
#############
from tensorflow.keras.utils import to_categorical

y_len = len(set(y_train))

# %%
y_train = to_categorical(y_train, y_len)
y_test = to_categorical(y_test, y_len)

x_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000, 10))

# %%
#############
# Your Code # Sequential
#############
keras.backend.clear_session()

model = keras.models.Sequential()

model.add(keras.layers.Input(shape=(x_train[1].shape)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(512, activation='relu'))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])

#### 모델 요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 575,050
# Trainable params: 575,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
#############
# Your Code # Functional
#############
keras.backend.clear_session()

a = keras.layers.Input(shape=(x_train[1].shape))
fl = keras.layers.Flatten()(a)
h = keras.layers.Dense(512, activation='relu')(fl)
h = keras.layers.Dense(256, activation='relu')(h)
h = keras.layers.Dense(128, activation='relu')(h)
h = keras.layers.Dense(64, activation='relu')(h)
b = keras.layers.Dense(10, activation='softmax')(h)

model = keras.models.Model(a,b)

model.compile(loss=keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])

#### 모델 요약
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 575,050
# Trainable params: 575,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
#############
# Your Code #
#############
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

# %%
#############
# Your Code #
#############
hist = model.fit(x_train, y_train, validation_split=0.2, callbacks=[es], verbose=1, epochs=1000, batch_size=64)
# Out:
# Epoch 1/1000
# 750/750 [==============================] - 5s 5ms/step - loss: 0.5151 - accuracy: 0.8116 - val_loss: 0.4250 - val_accuracy: 0.8441
# Epoch 2/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3734 - accuracy: 0.8616 - val_loss: 0.3576 - val_accuracy: 0.8705
# Epoch 3/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3362 - accuracy: 0.8744 - val_loss: 0.3435 - val_accuracy: 0.8784
# Epoch 4/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3077 - accuracy: 0.8842 - val_loss: 0.3220 - val_accuracy: 0.8853
# Epoch 5/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2916 - accuracy: 0.8899 - val_loss: 0.3519 - val_accuracy: 0.8715
# Epoch 6/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2740 - accuracy: 0.8985 - val_loss: 0.3380 - val_accuracy: 0.8758
# Epoch 7/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2601 - accuracy: 0.9028 - val_loss: 0.3140 - val_accuracy: 0.8864
# Epoch 8/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2504 - accuracy: 0.9047 - val_loss: 0.3182 - val_accuracy: 0.8862
# Epoch 9/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2419 - accuracy: 0.9088 - val_loss: 0.3468 - val_accuracy: 0.8809
# Epoch 10/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2289 - accuracy: 0.9125 - val_loss: 0.3407 - val_accuracy: 0.8892
# Epoch 11/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2193 - accuracy: 0.9166 - val_loss: 0.3184 - val_accuracy: 0.8921
# Epoch 12/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2134 - accuracy: 0.9193 - val_loss: 0.3163 - val_accuracy: 0.8885
# Epoch 13/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2044 - accuracy: 0.9221 - val_loss: 0.3457 - val_accuracy: 0.8832
# Epoch 14/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1975 - accuracy: 0.9253 - val_loss: 0.3244 - val_accuracy: 0.8939
# Epoch 15/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1901 - accuracy: 0.9278 - val_loss: 0.3180 - val_accuracy: 0.8947
# Epoch 16/1000
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1819 - accuracy: 0.9302 - val_loss: 0.3330 - val_accuracy: 0.8940
# Epoch 17/1000
# 739/750 [============================>.] - ETA: 0s - loss: 0.1756 - accuracy: 0.9327Restoring model weights from the end of the best epoch: 7.
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1757 - accuracy: 0.9326 - val_loss: 0.3323 - val_accuracy: 0.8961
# Epoch 17: early stopping

# %% [markdown]
# ## Visualize prediction
#
# 위에서 지키라고 한 사항들 안지키면 동작을 안할껄...?

# %%
score = model.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model.predict(x_test).argmax(axis=1)
# Out:
#  Test accuracy: 0.8773000240325928

# %%
####### 반복실행해보자

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index].reshape([28,-1])),cmap='gray')
    predict_index = y_hat[index]
    true_index = y_test[index].argmax(axis=0)
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))

# %%
plt.figure(figsize=(12,6))
plt.plot(hist.history['accuracy'], label='acc')
plt.plot(hist.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(12,6))
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>
